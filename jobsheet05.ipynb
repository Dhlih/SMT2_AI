# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhlih/SMT2_AI/blob/main/jobsheet05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Library

# %%
import pandas as pd

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('./Data.csv')
df
# Out:
#      Negara    Umur        Gaji Transaksi
# 0   Jakarta    44.0   8000000.0     Tidak
# 1   Bandung    27.0   6500000.0        Ya
# 2  Surabaya    30.0   4500000.0     Tidak
# 3   Bandung    38.0   7500000.0     Tidak
# 4  Surabaya    40.0         NaN        Ya
# 5   Jakarta    35.0  10000000.0        Ya
# 6   Bandung     NaN   8250000.0     Tidak
# 7   Jakarta    48.0   9750000.0        Ya
# 8  Surabaya  1000.0   7674000.0     Tidak
# 9   Jakarta    37.0   6700000.0        Ya

# %%
df.isnull().sum()
# Out:
# Negara       0
# Umur         1
# Gaji         1
# Transaksi    0
# dtype: int64

# %% [markdown]
# ## Mengatasi Missing Values dengan Drop Data

# %% [markdown]
# #### 1.

# %%
df = pd.read_csv('./Data.csv')
df.dropna(inplace=True)

df
# Out:
#      Negara    Umur        Gaji Transaksi
# 0   Jakarta    44.0   8000000.0     Tidak
# 1   Bandung    27.0   6500000.0        Ya
# 2  Surabaya    30.0   4500000.0     Tidak
# 3   Bandung    38.0   7500000.0     Tidak
# 5   Jakarta    35.0  10000000.0        Ya
# 7   Jakarta    48.0   9750000.0        Ya
# 8  Surabaya  1000.0   7674000.0     Tidak
# 9   Jakarta    37.0   6700000.0        Ya

# %% [markdown]
# ## Mengatasi Missing Values dengan Nilai Baru

# %% [markdown]
# #### 2.

# %%
df = pd.read_csv('./Data.csv')
df['Umur'] = df['Umur'].fillna(50)
df['Gaji'] = df['Gaji'].fillna(25000000)

# %%
df
# Out:
#      Negara    Umur        Gaji Transaksi
# 0   Jakarta    44.0   8000000.0     Tidak
# 1   Bandung    27.0   6500000.0        Ya
# 2  Surabaya    30.0   4500000.0     Tidak
# 3   Bandung    38.0   7500000.0     Tidak
# 4  Surabaya    40.0  25000000.0        Ya
# 5   Jakarta    35.0  10000000.0        Ya
# 6   Bandung    50.0   8250000.0     Tidak
# 7   Jakarta    48.0   9750000.0        Ya
# 8  Surabaya  1000.0   7674000.0     Tidak
# 9   Jakarta    37.0   6700000.0        Ya

# %% [markdown]
# ## 3. Ganti Data Kosong (NaN) pada Umur dan Gaji dengan Nilai Rata-Rata

# %%
df = pd.read_csv('./Data.csv')
mean_umur = df['Umur'].mean();
mean_gaji = df['Gaji'].mean();

df['Umur'] = df['Umur'].fillna(mean_umur)
df['Gaji'] = df['Gaji'].fillna(mean_gaji)

# %%
df
# Out:
#      Negara         Umur          Gaji Transaksi
# 0   Jakarta    44.000000  8.000000e+06     Tidak
# 1   Bandung    27.000000  6.500000e+06        Ya
# 2  Surabaya    30.000000  4.500000e+06     Tidak
# 3   Bandung    38.000000  7.500000e+06     Tidak
# 4  Surabaya    40.000000  7.652667e+06        Ya
# 5   Jakarta    35.000000  1.000000e+07        Ya
# 6   Bandung   144.333333  8.250000e+06     Tidak
# 7   Jakarta    48.000000  9.750000e+06        Ya
# 8  Surabaya  1000.000000  7.674000e+06     Tidak
# 9   Jakarta    37.000000  6.700000e+06        Ya

# %% [markdown]
# ## 4. Ganti Data Kosong (NaN) pada Umur dan Gaji dengan Nilai Median

# %%
df = pd.read_csv('./Data.csv')
mean_umur = df['Umur'].median();
mean_gaji = df['Gaji'].median();

df['Umur'] = df['Umur'].fillna(mean_umur)
df['Gaji'] = df['Gaji'].fillna(mean_gaji)

# %%
df
# Out:
#      Negara    Umur        Gaji Transaksi
# 0   Jakarta    44.0   8000000.0     Tidak
# 1   Bandung    27.0   6500000.0        Ya
# 2  Surabaya    30.0   4500000.0     Tidak
# 3   Bandung    38.0   7500000.0     Tidak
# 4  Surabaya    40.0   7674000.0        Ya
# 5   Jakarta    35.0  10000000.0        Ya
# 6   Bandung    38.0   8250000.0     Tidak
# 7   Jakarta    48.0   9750000.0        Ya
# 8  Surabaya  1000.0   7674000.0     Tidak
# 9   Jakarta    37.0   6700000.0        Ya

# %% [markdown]
# ## 5. Ganti Data Kosong (NaN) pada Umur dan Gaji dengan Nilai Modus

# %%
df = pd.read_csv('./Data.csv')
mean_umur = df['Umur'].mode()[0];
mean_gaji = df['Gaji'].mode()[0];

df['Umur'].fillna(mean_umur)
df['Gaji'].fillna(mean_gaji)
# Out:
# 0     8000000.0
# 1     6500000.0
# 2     4500000.0
# 3     7500000.0
# 4     4500000.0
# 5    10000000.0
# 6     8250000.0
# 7     9750000.0
# 8     7674000.0
# 9     6700000.0
# Name: Gaji, dtype: float64

# %%
df
# Out:
#      Negara    Umur        Gaji Transaksi
# 0   Jakarta    44.0   8000000.0     Tidak
# 1   Bandung    27.0   6500000.0        Ya
# 2  Surabaya    30.0   4500000.0     Tidak
# 3   Bandung    38.0   7500000.0     Tidak
# 4  Surabaya    40.0         NaN        Ya
# 5   Jakarta    35.0  10000000.0        Ya
# 6   Bandung     NaN   8250000.0     Tidak
# 7   Jakarta    48.0   9750000.0        Ya
# 8  Surabaya  1000.0   7674000.0     Tidak
# 9   Jakarta    37.0   6700000.0        Ya

# %% [markdown]
# ## 6. Apabila Ada Umur yang diatas 120 maka ubah menjadi 33

# %%
df = pd.read_csv('./Data.csv')

for x in df.index:
    if df.loc[x, 'Umur'] > 120:
        df.loc[x, 'Umur'] = 33

df
# Out:
#      Negara  Umur        Gaji Transaksi
# 0   Jakarta  44.0   8000000.0     Tidak
# 1   Bandung  27.0   6500000.0        Ya
# 2  Surabaya  30.0   4500000.0     Tidak
# 3   Bandung  38.0   7500000.0     Tidak
# 4  Surabaya  40.0         NaN        Ya
# 5   Jakarta  35.0  10000000.0        Ya
# 6   Bandung   NaN   8250000.0     Tidak
# 7   Jakarta  48.0   9750000.0        Ya
# 8  Surabaya  33.0   7674000.0     Tidak
# 9   Jakarta  37.0   6700000.0        Ya

# %% [markdown]
# ## TUGAS PRAKTIKUM

# %% [markdown]
# #### 1.

# %%
transaction_df = pd.read_csv("transactions_1k.csv")
customers_df = pd.read_csv("customers.csv")

# Hitung total transaksi per CustomerID
top_customers = transaction_df.groupby("CustomerID")["Price"].sum().reset_index()

# Urutkan dari yang paling tinggi
top_customers = top_customers.sort_values(by="Price", ascending=False).head()

# Gabungkan dengan data customer untuk ambil nama atau info lainnya
top_customers_named = top_customers.merge(customers_df, on="CustomerID")

# Tampilkan hasil
print(customers_df)
# Out:
#        CustomerID Segment Currency
# 0               3     SME      EUR
# 1               5     LAM      EUR
# 2               6     SME      EUR
# 3               7     LAM      EUR
# 4               9     SME      EUR
# ...           ...     ...      ...
# 32456       53307     SME      CZK
# 32457       53309     SME      CZK
# 32458       53311     SME      CZK
# 32459       53313     SME      CZK
# 32460       53314     SME      CZK
#
# [32461 rows x 3 columns]

# %% [markdown]
# #### 2.
